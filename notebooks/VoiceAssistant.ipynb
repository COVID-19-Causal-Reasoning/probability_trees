# %%
#@title Imports

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from probability_trees import MinCut, Critical, PTree

# %%
def voice_assistant1(bvar):
    if 'book_travel' not in bvar:
            return [(0, 'book_travel=0,order_food=0'),
                    (0.5, 'book_travel=1,order_food=0'),
                    (0.5, 'book_travel=0,order_food=1'),
                    (0, 'book_travel=1,order_food=1')
                   ]
    return None

# %%
def voice_assistant2(bvar):
    if 'book_travel' not in bvar:
            return [(0.5, 'book_travel=0'),
                    (0.5, 'book_travel=1'),
                   ]
    if 'order_food' not in bvar:
        if bvar['book']
        return [(0.4, 'order_food=0'),
                (0.6, 'order_food=1')]
    return None

# %%
def voice_assistant3(bvar):
    
    if 'order_food' not in bvar:
        return [(0.4, 'order_food=0'),
                (0.6, 'order_food=1')]
    if 'book_travel' not in bvar:
            return [(0.5, 'book_travel=0'),
                    (0.5, 'book_travel=1'),
                   ]
    return None

# %%
def voice_assistant4(bvar):
    
    if 'lifestyle' not in bvar:
        return [(0.4, 'lifestyle=healthy'),
                (0.6, 'lifestyle=unhealthy')]
    elif 'order_food' not in bvar:
        if bvar['lifestyle'] == 'healthy':
            return [(0.2, 'order_food=tacos'),
                    (0.8, 'order_food=salad'),
                   ]
        elif bvar['lifestyle'] == 'unhealthy':
            return [(0.5, 'order_food=tacos'),
                    (0.5, 'order_food=salad'),
                   ]
    return None

# %%
variables = ['order_veggie', 'order_meat']

# %%
va1 = PTree.fromFunc(voice_assistant1, 'Root = 1')
display(va.show(show_prob=True))

# %%
va2 = PTree.fromFunc(voice_assistant2, 'Root = 1')
display(va2.show(show_prob=True))

# %%
va3 = PTree.fromFunc(voice_assistant3, 'Root = 1')
display(va3.show(show_prob=True))

# %%
va4 = PTree.fromFunc(voice_assistant4, 'Root = 1')
display(va4.show(show_prob=True))
